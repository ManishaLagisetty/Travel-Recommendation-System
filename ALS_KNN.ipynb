# %%
import numpy as np
import pandas as pd

# remove war
import warnings
warnings.filterwarnings('ignore')

# this will allow ploting inside the notebook
# %matplotlib inline

# %% [markdown]
# ## Data Preprocessing

# %%
business = pd.read_csv('yelp_academic_dataset_business.csv', index_col=0, usecols=['business_id', 'name', 'attributes', 'categories', 'stars'])
review = pd.read_csv('yelp_academic_dataset_review.csv', index_col=0, usecols=['user_id', 'business_id', 'stars'])
user = pd.read_csv('yelp_academic_dataset_user.csv', index_col=0, usecols=['user_id', 'name'])

# %%
# Function that extract keys from the nested dictionary
import json
def extract_keys(attr, key):
    if attr == None or pd.isna(attr):
        return "{}"
    if key in attr:
        try:
            return ast.literal_eval(attr)[key]
        except:
            return "{}"

# convert string to dictionary
import ast
def str_to_dict(attr):
    if attr != None:
        return attr
    else:
        return {}

# %%
# extract values from nested attributes
business['BusinessParking'] = business.apply(lambda x: str_to_dict(extract_keys(x['attributes'], 'BusinessParking')), axis=1)
business['Ambience'] = business.apply(lambda x: str_to_dict(extract_keys(x['attributes'], 'Ambience')), axis=1)
business['GoodForMeal'] = business.apply(lambda x: str_to_dict(extract_keys(x['attributes'], 'GoodForMeal')), axis=1)
business['Dietary'] = business.apply(lambda x: str_to_dict(extract_keys(x['attributes'], 'Dietary')), axis=1)
business['Music'] = business.apply(lambda x: str_to_dict(extract_keys(x['attributes'], 'Music')), axis=1)
business['ByAppointmentOnly'] = business.apply(lambda x: str_to_dict(extract_keys(x['attributes'], 'ByAppointmentOnly')), axis=1)

# %%
# create table with attribute dummies
df_attr = pd.concat([ business['attributes'].apply(pd.Series), business['BusinessParking'].apply(pd.Series),
                    business['Ambience'].apply(pd.Series), business['GoodForMeal'].apply(pd.Series), 
                    business['Dietary'].apply(pd.Series) ], axis=1)
df_attr_dummies = pd.get_dummies(df_attr)
df_attr_dummies
# Out:
#                         0_{'AcceptsInsurance': 'False', 'BusinessAcceptsCreditCards': 'True', 'BikeParking': 'True', 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", 'ByAppointmentOnly': 'True', 'WiFi': "u'free'", 'WheelchairAccessible': 'True'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'False', 'BusinessAcceptsCreditCards': 'True', 'ByAppointmentOnly': 'True', 'BikeParking': 'True', 'WiFi': "u'free'", 'WheelchairAccessible': 'True'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'False', 'BusinessAcceptsCreditCards': 'True', 'ByAppointmentOnly': 'True', 'WiFi': "u'no'"}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'False', 'BusinessAcceptsCreditCards': 'True', 'WiFi': "u'free'"}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'False', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}", 'BusinessAcceptsCreditCards': 'True', 'BikeParking': 'True', 'ByAppointmentOnly': 'False', 'RestaurantsPriceRange2': '2'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'False', 'ByAppointmentOnly': 'True', 'WiFi': "u'free'", 'BusinessAcceptsCreditCards': 'True'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'False', 'Smoking': 'None', 'WiFi': 'None', 'BusinessParking': 'None', 'BusinessAcceptsCreditCards': 'True', 'ByAppointmentOnly': 'True'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'False', 'WiFi': "u'free'", 'BusinessAcceptsCreditCards': 'True', 'ByAppointmentOnly': 'True', 'WheelchairAccessible': 'False', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", 'BikeParking': 'True'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'True', 'BusinessAcceptsCreditCards': 'True', 'ByAppointmentOnly': 'False'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{'AcceptsInsurance': 'True', 'BusinessAcceptsCreditCards': 'True', 'ByAppointmentOnly': 'True', 'WheelchairAccessible': 'True'}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         ...  \
# business_id             ...
# Pns2l4eNsfO8kk83dixA6A  ...
# mpf3x-BjTdTEA3yCZrAYPw  ...
# tUFrWirKiKi_TAnsVWINQQ  ...
# MTSW4McQd7CbVtyjqoe9mw  ...
# mWMc6_wTdE0EUBKIGXDVfA  ...
# ...                     ...
# Pdin4DKMYBbXLXanNDNwLQ  ...
# N-4ZOrM_qAnzBiCsJ7-ENA  ...
# KqvaJX11rb4Hp70D8Dw4oQ  ...
# Yv6HUVu7fRMnt_NtGdVQBw  ...
# rwsVxJqln-0HZFg1zxWtwQ  ...
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': None, u'dinner': None, u'latenight': False, u'dessert': False}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': None, u'dinner': None, u'latenight': None, u'dessert': None}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': True, u'dinner': False, u'latenight': False, u'dessert': None}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': True, u'dinner': None, u'latenight': False, u'dessert': False}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': True, u'dinner': None, u'latenight': False, u'dessert': None}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': True, u'dinner': None, u'latenight': None, u'dessert': None}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': True, u'dinner': True, u'latenight': False, u'dessert': None}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                         0_{u'breakfast': True, u'brunch': True, u'lunch': True, u'dinner': True, u'latenight': None, u'dessert': True}  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                              False
# mpf3x-BjTdTEA3yCZrAYPw                                              False
# tUFrWirKiKi_TAnsVWINQQ                                              False
# MTSW4McQd7CbVtyjqoe9mw                                              False
# mWMc6_wTdE0EUBKIGXDVfA                                              False
# ...                                                                   ...
# Pdin4DKMYBbXLXanNDNwLQ                                              False
# N-4ZOrM_qAnzBiCsJ7-ENA                                              False
# KqvaJX11rb4Hp70D8Dw4oQ                                              False
# Yv6HUVu7fRMnt_NtGdVQBw                                              False
# rwsVxJqln-0HZFg1zxWtwQ                                              False
#
#                          0_{}   0_{}
# business_id
# Pns2l4eNsfO8kk83dixA6A  False  False
# mpf3x-BjTdTEA3yCZrAYPw  False  False
# tUFrWirKiKi_TAnsVWINQQ  False  False
# MTSW4McQd7CbVtyjqoe9mw  False  False
# mWMc6_wTdE0EUBKIGXDVfA  False  False
# ...                       ...    ...
# Pdin4DKMYBbXLXanNDNwLQ  False  False
# N-4ZOrM_qAnzBiCsJ7-ENA  False  False
# KqvaJX11rb4Hp70D8Dw4oQ  False  False
# Yv6HUVu7fRMnt_NtGdVQBw  False  False
# rwsVxJqln-0HZFg1zxWtwQ  False  False
#
# [10000 rows x 7565 columns]

# %%
df_categories_dummies = pd.Series(business['categories']).str.get_dummies(',')
df_categories_dummies
# Out:
#                          & Probates   ATV Rentals/Tours   Acai Bowls  \
# business_id
# Pns2l4eNsfO8kk83dixA6A            0                   0            0
# mpf3x-BjTdTEA3yCZrAYPw            0                   0            0
# tUFrWirKiKi_TAnsVWINQQ            0                   0            0
# MTSW4McQd7CbVtyjqoe9mw            0                   0            0
# mWMc6_wTdE0EUBKIGXDVfA            0                   0            0
# ...                             ...                 ...          ...
# Pdin4DKMYBbXLXanNDNwLQ            0                   0            0
# N-4ZOrM_qAnzBiCsJ7-ENA            0                   0            0
# KqvaJX11rb4Hp70D8Dw4oQ            0                   0            0
# Yv6HUVu7fRMnt_NtGdVQBw            0                   0            0
# rwsVxJqln-0HZFg1zxWtwQ            0                   0            0
#
#                          Accessories   Accountants   Acne Treatment  \
# business_id
# Pns2l4eNsfO8kk83dixA6A             0             0                0
# mpf3x-BjTdTEA3yCZrAYPw             0             0                0
# tUFrWirKiKi_TAnsVWINQQ             0             0                0
# MTSW4McQd7CbVtyjqoe9mw             0             0                0
# mWMc6_wTdE0EUBKIGXDVfA             0             0                0
# ...                              ...           ...              ...
# Pdin4DKMYBbXLXanNDNwLQ             0             0                0
# N-4ZOrM_qAnzBiCsJ7-ENA             0             0                0
# KqvaJX11rb4Hp70D8Dw4oQ             0             0                0
# Yv6HUVu7fRMnt_NtGdVQBw             0             0                0
# rwsVxJqln-0HZFg1zxWtwQ             0             0                0
#
#                          Active Life   Acupuncture   Addiction Medicine  \
# business_id
# Pns2l4eNsfO8kk83dixA6A             0             1                    0
# mpf3x-BjTdTEA3yCZrAYPw             0             0                    0
# tUFrWirKiKi_TAnsVWINQQ             0             0                    0
# MTSW4McQd7CbVtyjqoe9mw             0             0                    0
# mWMc6_wTdE0EUBKIGXDVfA             0             0                    0
# ...                              ...           ...                  ...
# Pdin4DKMYBbXLXanNDNwLQ             0             0                    0
# N-4ZOrM_qAnzBiCsJ7-ENA             0             0                    0
# KqvaJX11rb4Hp70D8Dw4oQ             0             0                    0
# Yv6HUVu7fRMnt_NtGdVQBw             0             0                    0
# rwsVxJqln-0HZFg1zxWtwQ             0             0                    0
#
#                          Adult  ...  Window Washing  Windows Installation  \
# business_id                     ...
# Pns2l4eNsfO8kk83dixA6A       0  ...               0                     0
# mpf3x-BjTdTEA3yCZrAYPw       0  ...               0                     0
# tUFrWirKiKi_TAnsVWINQQ       0  ...               0                     0
# MTSW4McQd7CbVtyjqoe9mw       0  ...               0                     0
# mWMc6_wTdE0EUBKIGXDVfA       0  ...               0                     0
# ...                        ...  ...             ...                   ...
# Pdin4DKMYBbXLXanNDNwLQ       0  ...               0                     0
# N-4ZOrM_qAnzBiCsJ7-ENA       0  ...               0                     0
# KqvaJX11rb4Hp70D8Dw4oQ       0  ...               0                     0
# Yv6HUVu7fRMnt_NtGdVQBw       0  ...               0                     0
# rwsVxJqln-0HZFg1zxWtwQ       0  ...               0                     0
#
#                         Windshield Installation & Repair  Wine Bars  Wineries  \
# business_id
# Pns2l4eNsfO8kk83dixA6A                                 0          0         0
# mpf3x-BjTdTEA3yCZrAYPw                                 0          0         0
# tUFrWirKiKi_TAnsVWINQQ                                 0          0         0
# MTSW4McQd7CbVtyjqoe9mw                                 0          0         0
# mWMc6_wTdE0EUBKIGXDVfA                                 0          0         0
# ...                                                  ...        ...       ...
# Pdin4DKMYBbXLXanNDNwLQ                                 0          0         0
# N-4ZOrM_qAnzBiCsJ7-ENA                                 0          0         0
# KqvaJX11rb4Hp70D8Dw4oQ                                 0          0         0
# Yv6HUVu7fRMnt_NtGdVQBw                                 0          0         0
# rwsVxJqln-0HZFg1zxWtwQ                                 0          0         0
#
#                         Women's Clothing  Wraps  Yelp Events  Yoga  Zoos
# business_id
# Pns2l4eNsfO8kk83dixA6A                 0      0            0     0     0
# mpf3x-BjTdTEA3yCZrAYPw                 0      0            0     0     0
# tUFrWirKiKi_TAnsVWINQQ                 0      0            0     0     0
# MTSW4McQd7CbVtyjqoe9mw                 0      0            0     0     0
# mWMc6_wTdE0EUBKIGXDVfA                 0      0            0     0     0
# ...                                  ...    ...          ...   ...   ...
# Pdin4DKMYBbXLXanNDNwLQ                 0      0            0     0     0
# N-4ZOrM_qAnzBiCsJ7-ENA                 0      0            0     0     0
# KqvaJX11rb4Hp70D8Dw4oQ                 0      0            0     0     0
# Yv6HUVu7fRMnt_NtGdVQBw                 0      0            0     0     0
# rwsVxJqln-0HZFg1zxWtwQ                 0      0            0     0     0
#
# [10000 rows x 1768 columns]

# %%
# pull out names and stars from rest table 
result = business[['name','stars']]
result
# Out:
#                                                  name  stars
# business_id
# Pns2l4eNsfO8kk83dixA6A       Abby Rappoport, LAC, CMQ    5.0
# mpf3x-BjTdTEA3yCZrAYPw                  The UPS Store    3.0
# tUFrWirKiKi_TAnsVWINQQ                         Target    3.5
# MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries    4.0
# mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery    4.5
# ...                                               ...    ...
# Pdin4DKMYBbXLXanNDNwLQ          Knuckle Dusters Vapor    5.0
# N-4ZOrM_qAnzBiCsJ7-ENA          Ricky's All Day Grill    3.0
# KqvaJX11rb4Hp70D8Dw4oQ   Admirals Club PHL Terminal F    4.0
# Yv6HUVu7fRMnt_NtGdVQBw  Las Palmas Mexican Restaurant    3.5
# rwsVxJqln-0HZFg1zxWtwQ      Adams Printing & Graphics    4.5
#
# [10000 rows x 2 columns]

# %%
# Concat all tables and drop Restaurant column
df_final = pd.concat([df_attr_dummies, df_categories_dummies, result], axis=1)
df_final.drop('Restaurants',inplace=True,axis=1)

# %%
# save the preprocessed data to disk
# df_final.to_csv('df_final.csv')

# %%
# load data from disk
# df_final = pd.read_csv('df_final.csv')

# %%
# Split the data into train and test sets
from sklearn.model_selection import train_test_split

train_df_final, test_df_final = train_test_split(df_final, test_size=0.2, random_state=1)

# %% [markdown]
# ## KNN

# %%
# Create X (all the features) and y (target)
X_train = train_df_final.iloc[:,:-2]
y_train = train_df_final['stars']
X_test = test_df_final.iloc[:,:-2]
y_test = test_df_final['stars']

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score

knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)

accuracy_train = knn.score(X_train, y_train)
accuracy_test = knn.score(X_test, y_test)

print(f"Score on training set: {accuracy_train}")
print(f"Score on test set: {accuracy_test}")
# Out:
# Score on training set: 0.3538484877861374
# Score on test set: 0.015490117512595214

# %% [markdown]
# ## Collaborative Filtering
#
# https://spark.apache.org/docs/latest/mllib-collaborative-filtering.html

# %%
# create numerical user and business as uid and pid

user_reset = user.reset_index()
user_reset = user_reset.reset_index().rename(columns={'index': 'uid'})
user_reset.head()

business_reset = business.reset_index()
business_reset = business_reset.reset_index().rename(columns={'index': 'pid'})
business_reset.head()
# Out:
#    pid             business_id                      name  stars  \
# 0    0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ    5.0
# 1    1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store    3.0
# 2    2  tUFrWirKiKi_TAnsVWINQQ                    Target    3.5
# 3    3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries    4.0
# 4    4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery    4.5
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food

# %%
# Merge review with user on user_id column
review_user = review.merge(user_reset, on='user_id', how='outer')
review_user.head()
# Out:
#                   user_id             business_id  stars       uid     name
# 0  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw    3.0  124234.0  Melanie
# 1  mh_-eMZ6K5RLWhZyISBhwA  d_tRshM-w6S4QxE4VVi8tQ    3.0  124234.0  Melanie
# 2  mh_-eMZ6K5RLWhZyISBhwA  8eDkw7CE0NKqMknPIu26fw    5.0  124234.0  Melanie
# 3  mh_-eMZ6K5RLWhZyISBhwA  w3giBYDmPWWnsNq5Sr2KQA    5.0  124234.0  Melanie
# 4  mh_-eMZ6K5RLWhZyISBhwA  tVfJPW14AeuAHDJeleWWdQ    3.0  124234.0  Melanie

# %%
# Merge review_user with business on business_id column
review_final = review_user.merge(business_reset, on='business_id', how='outer')
review_final = review_final.dropna()
review_final.head()
# Out:
#                   user_id             business_id  stars_x       uid   name_x  \
# 0  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw      3.0  124234.0  Melanie
# 1  5EGs7LX3Z8ZogvOOgNLsnA  XQfwVwDr-v0ZS3_CbbE5Xw      2.0  121817.0  Phyllis
# 2  q3Kv3wFOwu1Rd2I6T_VWOQ  XQfwVwDr-v0ZS3_CbbE5Xw      5.0   89372.0    Gabby
# 3  wmqsehbFirZPlAluJUakeQ  XQfwVwDr-v0ZS3_CbbE5Xw      3.0   34438.0  Charles
# 4  NMLvjdY7IOdtfU0TepvUuA  XQfwVwDr-v0ZS3_CbbE5Xw      2.0    9488.0     Zach
#
#       pid                        name_y  stars_y  \
# 0  1867.0  Turning Point of North Wales      3.0
# 1  1867.0  Turning Point of North Wales      3.0
# 2  1867.0  Turning Point of North Wales      3.0
# 3  1867.0  Turning Point of North Wales      3.0
# 4  1867.0  Turning Point of North Wales      3.0
#
#                                           attributes  \
# 0  {'NoiseLevel': "u'average'", 'HasTV': 'False',...
# 1  {'NoiseLevel': "u'average'", 'HasTV': 'False',...
# 2  {'NoiseLevel': "u'average'", 'HasTV': 'False',...
# 3  {'NoiseLevel': "u'average'", 'HasTV': 'False',...
# 4  {'NoiseLevel': "u'average'", 'HasTV': 'False',...
#
#                                           categories
# 0  Restaurants, Breakfast & Brunch, Food, Juice B...
# 1  Restaurants, Breakfast & Brunch, Food, Juice B...
# 2  Restaurants, Breakfast & Brunch, Food, Juice B...
# 3  Restaurants, Breakfast & Brunch, Food, Juice B...
# 4  Restaurants, Breakfast & Brunch, Food, Juice B...

# %%
# save the produced dataframe
# review_final.to_csv('review_final.csv')
# read it back
# review_final = pd.read_csv('review_final.csv')

# %%
from sklearn.model_selection import train_test_split

trainset, testset = train_test_split(review_final, test_size=0.2)  # You can adjust the test_size

# %%
# convert to (userID, productID, rating) tuple for train set

from tqdm.notebook import tqdm

trainset_tuples = []
for _, row in tqdm(trainset.iterrows()):
    try:
        trainset_tuples.append((int(row['uid']), int(row['pid']), row['stars_x']))
    except Exception as e:
        print(e)
        break
# Out:
# 0it [00:00, ?it/s]

# %%
# convert to (userID, productID, rating) tuple for test set

from tqdm.notebook import tqdm

testset_tuples = []
for _, row in tqdm(testset.iterrows()):
    try:
        testset_tuples.append((int(row['uid']), int(row['pid']), row['stars_x']))
    except Exception as e:
        pass
# Out:
# 0it [00:00, ?it/s]

# %%
import os
import sys

# set env to make PYSPARK connection more stable
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
os.environ['SPARK_MASTER_HOST'] = 'localhost'
os.environ['SPARK_LOCAL_IP'] = '127.0.0.1'

# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf

conf = SparkConf()
conf.set('spark.logConf', 'true')
conf.set('spark.driver.memory', '15g')

# Create a Spark session
spark = SparkSession.builder.config(conf=conf).getOrCreate()
spark.sparkContext.setLogLevel("OFF")

# Convert the list of tuples to an RDD using parallelize()
train_rdd = spark.sparkContext.parallelize(trainset_tuples)

# Convert the list of tuples to an RDD using parallelize()
test_rdd = spark.sparkContext.parallelize(testset_tuples)

# %%
from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

# Build the recommendation model using Alternating Least Squares
rank = 5
numIterations = 20
model = ALS.train(train_rdd, rank, numIterations, nonnegative=True)

# %%
# Evaluate the model on training data
testdata = test_rdd.map(lambda p: (p[0], p[1]))
predictions = model.predictAll(testdata).map(lambda r: ((r[0], r[1]), r[2]))
ratesAndPreds = test_rdd.map(lambda r: ((r[0], r[1]), r[2])).join(predictions)
MSE = ratesAndPreds.map(lambda r: (r[1][0] - r[1][1])**2).mean()
print("Mean Squared Error = " + str(MSE))
# Out:
# [Stage 731:===========================>                          (10 + 10) / 20]
# Mean Squared Error = 3.1609853087630433

# %%
# convert RDD to python list
pred = ratesAndPreds.map(lambda r: r[1][0]).collect()
gt = ratesAndPreds.map(lambda r: r[1][1]).collect()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# compute cosine similarity
cosine_similarity([pred, gt])
# Out:
# array([[1.        , 0.90103381],
#        [0.90103381, 1.        ]])

# %%
from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

# Save and load model

# model.save(spark.sparkContext, "myCollaborativeFilter2")
# model = MatrixFactorizationModel.load(spark.sparkContext, "myCollaborativeFilter2")

# %% [markdown]
# ## Example to Recommend for One User

# %%
# let's recommend for user 6
rec_user = review_final[review_final['uid'] == 6]
rec_user
# Out:
#                         user_id             business_id  stars_x  uid name_x  \
# 1665393  cxuxXkcihfCbqt5Byrup8Q  twNHYgtUkxoeFbLHxdhsOw      2.0  6.0    Rob
# 2228465  cxuxXkcihfCbqt5Byrup8Q  YqSW6uIkrF9a2h6iLgRw2w      3.0  6.0    Rob
# 2231682  cxuxXkcihfCbqt5Byrup8Q  ZJKGcR7J0n1DGbLqt1N5Vw      3.0  6.0    Rob
# 2922141  cxuxXkcihfCbqt5Byrup8Q  aDLT33YjIoNPxCXvGV9CcQ      4.0  6.0    Rob
# 2961148  cxuxXkcihfCbqt5Byrup8Q  PUwJCApOv4NcLBiG7xr2bg      2.0  6.0    Rob
# 2963087  cxuxXkcihfCbqt5Byrup8Q  0tysAE9vfgSshq9cdNuXxQ      2.0  6.0    Rob
# 3038419  cxuxXkcihfCbqt5Byrup8Q  qI561liErkfoWThrpsGGsA      4.0  6.0    Rob
# 4140051  cxuxXkcihfCbqt5Byrup8Q  1gWUE5Avh_pswlHhf813EQ      2.0  6.0    Rob
# 4893283  cxuxXkcihfCbqt5Byrup8Q  5r54nDwOmoq9w3-3ssy6dg      3.0  6.0    Rob
# 5754863  cxuxXkcihfCbqt5Byrup8Q  m01BobN463t2CiAc-F7G0Q      1.0  6.0    Rob
#
#               pid                         name_y  stars_y  \
# 1665393   11973.0  Daddy Jack's Restaurant & Bar      3.5
# 2228465   51245.0         Mitchell's Fish Market      3.5
# 2231682   77764.0      Bub's Burgers & Ice Cream      4.0
# 2922141   36201.0                Roselli's Pizza      3.5
# 2961148   62521.0                 Bazbeaux Pizza      4.0
# 2963087  111563.0                Bistro de Paris      3.0
# 3038419  131008.0      Sesame Chinese Restaurant      3.5
# 4140051   13094.0     Roscoe's Tacos - Greenwood      3.5
# 4893283   16576.0                   Panera Bread      2.0
# 5754863  141869.0           Yen Ching Restaurant      3.0
#
#                                                 attributes  \
# 1665393  {'GoodForKids': 'False', 'BusinessAcceptsCredi...
# 2228465  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 2231682  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 2922141  {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 2961148  {'Alcohol': "u'beer_and_wine'", 'OutdoorSeatin...
# 2963087  {'RestaurantsDelivery': 'False', 'RestaurantsG...
# 3038419  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 4140051  {'HasTV': 'False', 'BikeParking': 'False', 'Bu...
# 4893283  {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 5754863  {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
#
#                                                 categories
# 1665393  Specialty Food, Food, American (New), American...
# 2228465  Restaurants, Steakhouses, American (Traditiona...
# 2231682  Food, Ice Cream & Frozen Yogurt, Burgers, Rest...
# 2922141  Restaurants, Caterers, Italian, Pizza, Event P...
# 2961148                                 Restaurants, Pizza
# 2963087                                Restaurants, French
# 3038419                   Restaurants, Vegetarian, Chinese
# 4140051                      Restaurants, Mexican, Tex-Mex
# 4893283  Food, Breakfast & Brunch, Salad, Sandwiches, S...
# 5754863                               Restaurants, Chinese

# %%
# create the input data for user 4 to trigger recommendations
pred_list = []
for pid in range(int(review_final['pid'].max())):
    pred_list.append((6, pid))
pred_rdd = spark.sparkContext.parallelize(pred_list)
predictions = model.predictAll(pred_rdd).map(lambda r: (r[0], r[1], r[2]))

# %%
# sort the recommnedations by predicted stars
pred_res = predictions.collect()
pred_df = pd.DataFrame(pred_res, columns=['uid', 'pid', 'stars_x'])
merged = pred_df.merge(business_reset, on='pid', how='outer')
sorted_df = merged.sort_values(by='stars', ascending=False)
sorted_df.head()
# Out:
#         uid     pid   stars_x             business_id  \
# 137445  NaN    9805       NaN  l3rvbtt8SoD2rBtGOVEUsw
# 40574   6.0   85282  2.607497  6kmexpuivgntmonKoE66eQ
# 16624   6.0   70351  4.070431  zbUyNmrSIhPSh4HOosX2vQ
# 63009   6.0  112074  3.244986  XjeIHZZNEXO9f_eAR1rqpA
# 118572  6.0  136068  3.074666  5HRLUzKrs27kuQhgJQijnQ
#
#                                    name  stars  \
# 137445   Chesterbrook Academy Preschool    5.0
# 40574               Robert A Scott, DDS    5.0
# 16624               Bella Capelli Salon    5.0
# 63009   Help Air Conditioning & Heating    5.0
# 118572                  Spaddy's Coffee    5.0
#
#                                                attributes  \
# 137445                                                NaN
# 40574   {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 16624   {'ByAppointmentOnly': 'True', 'GoodForKids': '...
# 63009   {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 118572  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
#
#                                                categories
# 137445  Local Services, Education, Preschools, Child C...
# 40574   Dentists, Oral Surgeons, General Dentistry, He...
# 16624                          Hair Salons, Beauty & Spas
# 63009      Home Services, Heating & Air Conditioning/HVAC
# 118572  Breakfast & Brunch, Coffee & Tea, Food, Food T...
